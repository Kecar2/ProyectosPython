# %%
import pandas as pd
import requests
import time

# %%
url = 'https://sedeaplicaciones.minetur.gob.es/ServiciosRESTCarburantes/PreciosCarburantes/EstacionesTerrestres/'

# %%
url
# Out:
# 'https://sedeaplicaciones.minetur.gob.es/ServiciosRESTCarburantes/PreciosCarburantes/EstacionesTerrestres/'

# %%
res = requests.get(url).json()

# %%
res
# Out:
# {'Fecha': '08/10/2022 14:37:21',
#  'ListaEESSPrecio': [{'C.P.': '02250',
#    'Dirección': 'AVENIDA CASTILLA LA MANCHA, 26',
#    'Horario': 'L-D: 07:00-22:00',
#    'Latitud': '39,211417',
#    'Localidad': 'ABENGIBRE',
#    'Longitud (WGS84)': '-1,539167',
#    'Margen': 'D',
#    'Municipio': 'Abengibre',
#    'Precio Biodiesel': '',
#    'Precio Bioetanol': '',
#    'Precio Gas Natural Comprimido': '',
#    'Precio Gas Natural Licuado': '',
#    'Precio Gases licuados del petróleo': '',
#    'Precio Gasoleo A': '1,879',
#    'Precio Gasoleo B': '1,450',
#    'Precio Gasoleo Premium': '',
#    'Precio Gasolina 95 E10': '',
#    'Precio Gasolina 95 E5': '1,739',
#    'Precio Gasolina 95 E5 Premium': '',
#    'Precio Gasolina 98 E10': '',
#    'Precio Gasolina 98 E5': '',
#    'Precio Hidrogeno': '',
#    'Provincia': 'ALBACETE',
#    'Remisión': 'dm',
#    'Rótulo': 'Nº 10.935',
#    'Tipo Venta': 'P',
#    '% BioEtanol': '0,0',
#    '% Éster metílico': '0,0',
# ...

# %%
res.keys()
# Out:
# dict_keys(['Fecha', 'ListaEESSPrecio', 'Nota', 'ResultadoConsulta'])

# %%
res['ListaEESSPrecio']
# Out:
# [{'C.P.': '02250',
#   'Dirección': 'AVENIDA CASTILLA LA MANCHA, 26',
#   'Horario': 'L-D: 07:00-22:00',
#   'Latitud': '39,211417',
#   'Localidad': 'ABENGIBRE',
#   'Longitud (WGS84)': '-1,539167',
#   'Margen': 'D',
#   'Municipio': 'Abengibre',
#   'Precio Biodiesel': '',
#   'Precio Bioetanol': '',
#   'Precio Gas Natural Comprimido': '',
#   'Precio Gas Natural Licuado': '',
#   'Precio Gases licuados del petróleo': '',
#   'Precio Gasoleo A': '1,879',
#   'Precio Gasoleo B': '1,450',
#   'Precio Gasoleo Premium': '',
#   'Precio Gasolina 95 E10': '',
#   'Precio Gasolina 95 E5': '1,739',
#   'Precio Gasolina 95 E5 Premium': '',
#   'Precio Gasolina 98 E10': '',
#   'Precio Gasolina 98 E5': '',
#   'Precio Hidrogeno': '',
#   'Provincia': 'ALBACETE',
#   'Remisión': 'dm',
#   'Rótulo': 'Nº 10.935',
#   'Tipo Venta': 'P',
#   '% BioEtanol': '0,0',
#   '% Éster metílico': '0,0',
#   'IDEESS': '4375',
#   'IDMunicipio': '52',
#   'IDProvincia': '02',
#   'IDCCAA': '07'},
# ...

# %%
type(res['ListaEESSPrecio'])
# Out:
# list

# %%
type(res['ListaEESSPrecio'][0])
# Out:
# dict

# %%
df = pd.DataFrame(res['ListaEESSPrecio'])

# %%
df.head()
# Out:
#     C.P.                                          Dirección  \
# 0  02250                     AVENIDA CASTILLA LA MANCHA, 26
# 1  02152                                    CR CM-332, 46,4
# 2  02001  CALLE PRINCIPE DE ASTURIAS (POLÍGONO DE ROMICA...
# 3  02001                     CALLE FEDERICO GARCIA LORCA, 5
# 4  02001                            AVENIDA 1º DE MAYO, S/N
#
#                             Horario    Latitud  Localidad Longitud (WGS84)  \
# 0                  L-D: 07:00-22:00  39,211417  ABENGIBRE        -1,539167
# 1                   L-D: 7:00-23:00  39,100389     ALATOZ        -1,346083
# 2                  L-D: 06:00-21:30  39,054694   ALBACETE        -1,832000
# 3                  L-S: 05:00-23:00  38,997722   ALBACETE        -1,846361
# 4  L-S: 08:00-22:00; D: 09:00-21:00  38,985667   ALBACETE        -1,868500
#
#   Margen  Municipio Precio Biodiesel Precio Bioetanol  ... Provincia Remisión  \
# ...

# %%
df.columns
# Out:
# Index(['C.P.', 'Dirección', 'Horario', 'Latitud', 'Localidad',
#        'Longitud (WGS84)', 'Margen', 'Municipio', 'Precio Biodiesel',
#        'Precio Bioetanol', 'Precio Gas Natural Comprimido',
#        'Precio Gas Natural Licuado', 'Precio Gases licuados del petróleo',
#        'Precio Gasoleo A', 'Precio Gasoleo B', 'Precio Gasoleo Premium',
#        'Precio Gasolina 95 E10', 'Precio Gasolina 95 E5',
#        'Precio Gasolina 95 E5 Premium', 'Precio Gasolina 98 E10',
#        'Precio Gasolina 98 E5', 'Precio Hidrogeno', 'Provincia', 'Remisión',
#        'Rótulo', 'Tipo Venta', '% BioEtanol', '% Éster metílico', 'IDEESS',
#        'IDMunicipio', 'IDProvincia', 'IDCCAA'],
#       dtype='object')

# %%
df.rename({'Precio Gasoleo A': 'Precio_Gasoleo_A', 'Precio Gasoleo Premium': 'Precio_Gasoleo_Premium','Precio Gasolina 95 E5': 'Precio_Gasolina_95_E5', 'Precio Gasolina 98 E5': 'Precio_Gasolina_98_E5'}, axis=1, inplace=True)

# %%
slim_df = df[['C.P.','Dirección','Horario','Localidad','Municipio','Provincia','Rótulo','Precio_Gasoleo_A','Precio_Gasoleo_Premium','Precio_Gasolina_95_E5','Precio_Gasolina_98_E5']]

# %%
slim_df.head()
# Out:
#     C.P.                                          Dirección  \
# 0  02250                     AVENIDA CASTILLA LA MANCHA, 26
# 1  02152                                    CR CM-332, 46,4
# 2  02001  CALLE PRINCIPE DE ASTURIAS (POLÍGONO DE ROMICA...
# 3  02001                     CALLE FEDERICO GARCIA LORCA, 5
# 4  02001                            AVENIDA 1º DE MAYO, S/N
#
#                             Horario  Localidad  Municipio Provincia  \
# 0                  L-D: 07:00-22:00  ABENGIBRE  Abengibre  ALBACETE
# 1                   L-D: 7:00-23:00     ALATOZ     Alatoz  ALBACETE
# 2                  L-D: 06:00-21:30   ALBACETE   Albacete  ALBACETE
# 3                  L-S: 05:00-23:00   ALBACETE   Albacete  ALBACETE
# 4  L-S: 08:00-22:00; D: 09:00-21:00   ALBACETE   Albacete  ALBACETE
#
#       Rótulo Precio_Gasoleo_A Precio_Gasoleo_Premium Precio_Gasolina_95_E5  \
# 0  Nº 10.935            1,879                                        1,739
# ...

# %%
plt = slim_df.Precio_Gasoleo_A.hist(figsize=(12,8), bins=20)

# %%
slim_df.Precio_Gasoleo_Premium.hist(figsize=(12,8), bins=20)
# Out:
# <AxesSubplot:>
